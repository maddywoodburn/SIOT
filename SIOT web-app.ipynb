# %%
pip install jupyter-dash --user
# Out:
# Requirement already satisfied: jupyter-dash in /Users/Maddy/.local/lib/python3.7/site-packages (0.4.0)
# Requirement already satisfied: requests in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from jupyter-dash) (2.22.0)
# Requirement already satisfied: ansi2html in /Users/Maddy/.local/lib/python3.7/site-packages (from jupyter-dash) (1.6.0)
# Requirement already satisfied: ipython in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from jupyter-dash) (7.8.0)
# Requirement already satisfied: ipykernel in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from jupyter-dash) (5.1.2)
# Requirement already satisfied: dash in /Users/Maddy/.local/lib/python3.7/site-packages (from jupyter-dash) (2.0.0)
# Requirement already satisfied: flask in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from jupyter-dash) (1.1.1)
# Requirement already satisfied: retrying in /Users/Maddy/.local/lib/python3.7/site-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from requests->jupyter-dash) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from requests->jupyter-dash) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from requests->jupyter-dash) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from requests->jupyter-dash) (1.24.2)
# Requirement already satisfied: backcall in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (0.1.0)
# Requirement already satisfied: pygments in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (2.4.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (41.4.0)
# Requirement already satisfied: pickleshare in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (4.3.3)
# Requirement already satisfied: decorator in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (4.4.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (4.7.0)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (0.1.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (2.0.10)
# Requirement already satisfied: jedi>=0.10 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipython->jupyter-dash) (0.15.1)
# Requirement already satisfied: jupyter-client in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipykernel->jupyter-dash) (5.3.3)
# Requirement already satisfied: tornado>=4.2 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from ipykernel->jupyter-dash) (6.0.3)
# Requirement already satisfied: plotly>=5.0.0 in /Users/Maddy/.local/lib/python3.7/site-packages (from dash->jupyter-dash) (5.4.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/Maddy/.local/lib/python3.7/site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/Maddy/.local/lib/python3.7/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: flask-compress in /Users/Maddy/.local/lib/python3.7/site-packages (from dash->jupyter-dash) (1.10.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/Maddy/.local/lib/python3.7/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: click>=5.1 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from flask->jupyter-dash) (7.0)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from flask->jupyter-dash) (0.16.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from flask->jupyter-dash) (2.10.3)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from flask->jupyter-dash) (1.1.0)
# Requirement already satisfied: six>=1.7.0 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from retrying->jupyter-dash) (1.12.0)
# Requirement already satisfied: ipython-genutils in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.2->ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython->jupyter-dash) (0.6.0)
# Requirement already satisfied: wcwidth in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->jupyter-dash) (0.1.7)
# Requirement already satisfied: parso>=0.5.0 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython->jupyter-dash) (0.5.1)
# Requirement already satisfied: pyzmq>=13 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter-dash) (18.1.0)
# Requirement already satisfied: jupyter-core in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter-dash) (4.5.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter-dash) (2.8.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/Maddy/.local/lib/python3.7/site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: brotli in /Users/Maddy/.local/lib/python3.7/site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/bobwoodburn/opt/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10.1->flask->jupyter-dash) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output, State
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr


import plotly.io as pio

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']


plt.rcParams["figure.figsize"] = (20,3)

# prep strava data
strava_data2 = pd.read_csv("Strava_readings.csv")
strava_data2['Date'] = pd.to_datetime(strava_data2['Date'])
strava_data2 = strava_data2.resample('H', on='Date').sum()

# prep light data
light_intensity2 = pd.read_csv("Photosensor_readings.csv")
light_intensity2['Date'] = pd.to_datetime(light_intensity2['Date'])
light_intensity2 = light_intensity2.resample('H', on='Date').mean()
#print(light_intensity2)

dataframe = light_intensity2.copy() # copy the dataframe to merge the two
#dataframe.dropna() # this removes all hours without light intensity - use instead of the ffill() command below
dataframe['Kudos'] = strava_data2['Kudos']
dataframe['Distance'] = strava_data2['Distance']
dataframe['Pace'] = strava_data2['Pace']
dataframe['Elapsed time'] = strava_data2['Elapsed time']

# use this code to forward fill light intensities to times that don't have them, instead of the dropna() command above
dataframe['Light Intensity'] = dataframe['Light Intensity'].ffill()
dataframe = dataframe.fillna(0) # this replaces empty strava data with 0s

# Load Data
df = dataframe
#print(df)

tabs_styles = {'zIndex': 99, 'display': 'inlineBlock', 'height': '4vh', 'width': '12vw',
               'position': 'fixed', "background": "#323130", 'top': '12.5vh', 'left': '7.5vw',
               'border': 'grey', 'border-radius': '4px'}


# Build App
app = JupyterDash(__name__, external_stylesheets=external_stylesheets)


colors = {
    'background': '#FFFFFF',
    'text': '#0047ab'
}


fig1 = px.line(df, y=["Light Intensity", "Distance"])
fig2 = px.line(df, y=["Light Intensity", "Elapsed time"])


#fig.update_layout(
#    plot_bgcolor=colors['background'],
#    paper_bgcolor=colors['background'],
 #   font_color=colors['text']

#)


app.layout = html.Div(


    style={'backgroundColor': colors['background']}, children=[
    html.H1(
        children='Sensing & IOT - coursework 2',
        style={
            'textAlign': 'center',
            'color': colors['text'],
            'font-family': 'sans-serif'
        }  
    ),

    html.Div(children='Can we correlate light intensity with features of my Strava Actvities?', 
        style={
            'textAlign': 'center',
            'color': colors['text'],
            'font-family': 'sans-serif'
    }),
    
    dcc.Tabs([
        dcc.Tab(label='Light Intensity and Distance',   
                style={
            'textAlign': 'center',
            'color': colors['text'],
            'font-family': 'sans-serif'
        },
                children=[
            
            dcc.Graph(
                id = "Light intensity distance graph",
          
                figure=fig1
                     
            )
           
    
        ]),
    
     dcc.Tab(label='Light Intensity and Elapsed Time', 
             style={
            'textAlign': 'center',
            'color': colors['text'],
            'font-family': 'sans-serif'
        },
             children=[
            
        dcc.Graph(
            id = "Light intensity elapsed time graph",
            
            figure=fig2,
            
            
                     
            )
        ]),
        
       dcc.Tab(label='Data actuation', 
             style={
            'textAlign': 'center',
            'color': colors['text'],
            'font-family': 'sans-serif'
        },
             children=[
            
      html.Div([
        dcc.Input(id='input-1-state', type='text', value='How light is it outside?'),
        dcc.Input(id='input-2-state', type='text', value='How are you feeling?'),
        html.Button(id='submit-button-state', n_clicks=0, children='Submit'),
        html.Div(id='output-state')
        
])
        ]),
        
   
]) 
    
   
])
      
@app.callback(Output('output-state', 'children'),
              Input('submit-button-state', 'n_clicks'),
              State('input-1-state', 'value'),
              State('input-2-state', 'value'))
def update_output(n_clicks, input1, input2):
    if n_clicks ==1:
        return u'''
            It is "{}" outside,
            you feel "{}",
            And you have pressed this button {} times, which means you should probably go for a run
        
            '''.format(input1, input2,n_clicks)
       
        n_clicks = 0
   

# Run app and display result inline in the notebook
app.run_server(mode='external', debug=True) #to run locally use mode="inline" and to run externally use mode="external"
# Out:
# Dash app running on http://127.0.0.1:8050/
